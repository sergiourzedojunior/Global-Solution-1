# %%
import sqlite3
import pandas as pd
# Correto — caminho absoluto para o banco certo
from pathlib import Path
db_path = Path("../db/gs2025.db").resolve()
con = sqlite3.connect(db_path)

print(pd.read_sql("SELECT name FROM sqlite_master WHERE type='table'", con))
# Out:
#                   name
# 0      indicadores_udh
# 1        igv_resultado
# 2  indicadores_udh_all
# 3    igv_resultado_all

# %%
df = pd.read_sql("SELECT * FROM indicadores_udh LIMIT 5", con)
df.head()
# Out:
#           cod_id      udh_atlas  \
# 0  1320130800001  1320130800001
# 1  1320130800002  1320130800002
# 2  1320130800003  1320130800003
# 3  1320130800004  1320130800004
# 4  1320130800005  1320130800005
#
#                                             nome_udh  codmun6        nome_mun  \
# 0                                       Campo Grande   320130  Cariacica (ES)
# 1  São Geraldo / Cruzeiro do Sul / Morada de Sant...   320130  Cariacica (ES)
# 2                                        São Conrado   320130  Cariacica (ES)
# 3                            Vera Cruz / São Conrado   320130  Cariacica (ES)
# 4        Jardim América / Vale Esperança / Vera Cruz   320130  Cariacica (ES)
#
#    coduf nome_uf  codrm                 nome_rm   ano  ...  t_flfund_tudo  \
# 0     32      ES  63200  RM Grande Vitória (ES)  2000  ...          98.15
# 1     32      ES  63200  RM Grande Vitória (ES)  2000  ...          95.40
# 2     32      ES  63200  RM Grande Vitória (ES)  2000  ...          88.36
# 3     32      ES  63200  RM Grande Vitória (ES)  2000  ...          88.48
# 4     32      ES  63200  RM Grande Vitória (ES)  2000  ...          97.89
#
#    t_flmed_tudo  t_flbas_tudo  t_fund11a13_tudo  i_escolaridade  i_freq_prop  \
# 0         70.85         95.80             91.84           0.656        0.757
# 1         69.93         94.96             85.68           0.549        0.682
# 2         25.53         84.09             73.90           0.268        0.358
# 3         15.53         85.12             60.50           0.492        0.608
# 4         67.77         96.27             93.47           0.573        0.693
#
#     idhm  idhm_e  idhm_l  idhm_r
# 0  0.778   0.722   0.835   0.781
# 1  0.710   0.634   0.806   0.701
# 2  0.506   0.325   0.715   0.557
# 3  0.670   0.567   0.779   0.680
# 4  0.726   0.650   0.818   0.720
#
# [5 rows x 229 columns]

# %%
df = pd.read_sql("SELECT * FROM indicadores_udh LIMIT 5", con)
df.columns
# Out:
# Index(['cod_id', 'udh_atlas', 'nome_udh', 'codmun6', 'nome_mun', 'coduf',
#        'nome_uf', 'codrm', 'nome_rm', 'ano',
#        ...
#        't_flfund_tudo', 't_flmed_tudo', 't_flbas_tudo', 't_fund11a13_tudo',
#        'i_escolaridade', 'i_freq_prop', 'idhm', 'idhm_e', 'idhm_l', 'idhm_r'],
#       dtype='object', length=229)

# %%
for col in df.columns:
    print(col)
# Out:
# cod_id
# udh_atlas
# nome_udh
# codmun6
# nome_mun
# coduf
# nome_uf
# codrm
# nome_rm
# ano
# espvida
# fectot
# mort1
# mort5
# sobre40
# sobre60
# razdep
# t_env
# e_anosestudo
# t_analf11a14
# t_analf15a17
# t_analf15m
# t_analf18a24
# t_analf18m
# t_analf25a29
# t_analf25m
# t_atraso_2_basico
# t_atraso_2_fund
# t_fbbas
# t_fbfund
# t_fbmed
# t_fbsuper
# t_flbas
# t_flfund
# t_flmed
# t_flsuper
# t_freq0a5
# t_freq15a17
# t_freq18a24
# t_freq25a29
# t_freq5a6
# t_freq6a14
# t_freq6a17
# t_freqfund1517
# t_freqfund1824
# t_freqmed1824
# t_fund11a13
# t_fund15a17
# t_fund18a24
# t_fund18m
# t_fund25m
# t_med18a20
# t_med18a24
# t_med18m
# t_med25m
# t_super25m
# corte1
# corte2
# corte3
# corte4
# corte9
# gini
# pind
# pindcri
# pmpob
# pmpobcri
# ppob
# ppobcri
# pren10ricos
# pren20
# pren20ricos
# pren40
# pren60
# pren80
# prentrab
# r1040
# r2040
# rdpc
# rdpc1
# rdpc10
# rdpc2
# rdpc3
# rdpc4
# rdpc5
# rdpct
# rind
# rmpob
# rpob
# theil
# p_agro
# p_com
# p_constr
# p_extr
# p_serv
# p_siup
# p_transf
# cpr
# emp
# p_formal
# trabcc
# trabpub
# trabsc
# p_fund
# p_med
# p_super
# ren0
# ren1
# ren2
# ren3
# ren5
# renocup
# theiltrab
# t_ativ1014
# t_ativ1517
# t_ativ1824
# t_ativ18m
# t_ativ2529
# t_des1014
# t_des1517
# t_des1824
# t_des18m
# t_des2529
# t_agua
# t_banagua
# t_dens
# t_lixo
# t_luz
# agua_esgoto
# parede
# t_crifundin_todos
# t_fora0a5
# t_fora6a14
# t_fundin_todos
# t_fundin_todos_mmeio
# t_fundin18minf
# t_m10a17cf
# t_mulchefefif014
# t_nestuda_ntrab_mmeio
# t_ocupdesloc_1
# t_rmaxidoso
# t_sluz
# t_vulnera_nestuda_ntrab_mmeio
# t_vulnera_mulchefe
# t_vulnera_rmaxidoso
# t_vulnera_ocupdesloc_13
# homem0a4
# homem10a14
# homem15a19
# homem20a24
# homem25a29
# homem30a34
# homem35a39
# homem40a44
# homem45a49
# homem50a54
# homem55a59
# homem5a9
# homem60a64
# homem65a69
# homem70a74
# homem75a79
# homens80
# homemtot
# mulh0a4
# mulh10a14
# mulh15a19
# mulh20a24
# mulh25a29
# mulh30a34
# mulh35a39
# mulh40a44
# mulh45a49
# mulh50a54
# mulh55a59
# mulh5a9
# mulh60a64
# mulh65a69
# mulh70a74
# mulh75a79
# mulher80
# mulhertot
# pea1014
# pea1517
# pea18m
# peso1
# peso1114
# peso1113
# peso1214
# peso13
# peso15
# peso1517
# peso1524
# peso1618
# peso18
# peso1820
# peso1824
# peso1921
# peso25
# peso4
# peso5
# peso6
# peso610
# peso617
# peso65
# pesom1014
# pesom1517
# pesom15m
# pesom25m
# pesorur
# pesotot
# pesourb
# pia
# pia1014
# pia1517
# pia18m
# pop
# t_fbfund_tudo
# t_fbmed_tudo
# t_fbbas_tudo
# t_flfund_tudo
# t_flmed_tudo
# t_flbas_tudo
# t_fund11a13_tudo
# i_escolaridade
# i_freq_prop
# idhm
# idhm_e
# idhm_l
# idhm_r

# %%
list(df.columns)
# Out:
# ['cod_id',
#  'udh_atlas',
#  'nome_udh',
#  'codmun6',
#  'nome_mun',
#  'coduf',
#  'nome_uf',
#  'codrm',
#  'nome_rm',
#  'ano',
#  'espvida',
#  'fectot',
#  'mort1',
#  'mort5',
#  'sobre40',
#  'sobre60',
#  'razdep',
#  't_env',
#  'e_anosestudo',
#  't_analf11a14',
#  't_analf15a17',
#  't_analf15m',
#  't_analf18a24',
#  't_analf18m',
#  't_analf25a29',
#  't_analf25m',
#  't_atraso_2_basico',
#  't_atraso_2_fund',
#  't_fbbas',
#  't_fbfund',
#  't_fbmed',
#  't_fbsuper',
#  't_flbas',
#  't_flfund',
#  't_flmed',
#  't_flsuper',
#  't_freq0a5',
#  't_freq15a17',
#  't_freq18a24',
#  't_freq25a29',
#  't_freq5a6',
#  't_freq6a14',
#  't_freq6a17',
#  't_freqfund1517',
#  't_freqfund1824',
#  't_freqmed1824',
#  't_fund11a13',
#  't_fund15a17',
#  't_fund18a24',
#  't_fund18m',
#  't_fund25m',
#  't_med18a20',
#  't_med18a24',
#  't_med18m',
#  't_med25m',
#  't_super25m',
#  'corte1',
#  'corte2',
#  'corte3',
#  'corte4',
#  'corte9',
#  'gini',
#  'pind',
#  'pindcri',
#  'pmpob',
#  'pmpobcri',
#  'ppob',
#  'ppobcri',
#  'pren10ricos',
#  'pren20',
#  'pren20ricos',
#  'pren40',
#  'pren60',
#  'pren80',
#  'prentrab',
#  'r1040',
#  'r2040',
#  'rdpc',
#  'rdpc1',
#  'rdpc10',
#  'rdpc2',
#  'rdpc3',
#  'rdpc4',
#  'rdpc5',
#  'rdpct',
#  'rind',
#  'rmpob',
#  'rpob',
#  'theil',
#  'p_agro',
#  'p_com',
#  'p_constr',
#  'p_extr',
#  'p_serv',
#  'p_siup',
#  'p_transf',
#  'cpr',
#  'emp',
#  'p_formal',
#  'trabcc',
#  'trabpub',
#  'trabsc',
#  'p_fund',
#  'p_med',
#  'p_super',
#  'ren0',
#  'ren1',
#  'ren2',
#  'ren3',
#  'ren5',
#  'renocup',
#  'theiltrab',
#  't_ativ1014',
#  't_ativ1517',
#  't_ativ1824',
#  't_ativ18m',
#  't_ativ2529',
#  't_des1014',
#  't_des1517',
#  't_des1824',
#  't_des18m',
#  't_des2529',
#  't_agua',
#  't_banagua',
#  't_dens',
#  't_lixo',
#  't_luz',
#  'agua_esgoto',
#  'parede',
#  't_crifundin_todos',
#  't_fora0a5',
#  't_fora6a14',
#  't_fundin_todos',
#  't_fundin_todos_mmeio',
#  't_fundin18minf',
#  't_m10a17cf',
#  't_mulchefefif014',
#  't_nestuda_ntrab_mmeio',
#  't_ocupdesloc_1',
#  't_rmaxidoso',
#  't_sluz',
#  't_vulnera_nestuda_ntrab_mmeio',
#  't_vulnera_mulchefe',
#  't_vulnera_rmaxidoso',
#  't_vulnera_ocupdesloc_13',
#  'homem0a4',
#  'homem10a14',
#  'homem15a19',
#  'homem20a24',
#  'homem25a29',
#  'homem30a34',
#  'homem35a39',
#  'homem40a44',
#  'homem45a49',
#  'homem50a54',
#  'homem55a59',
#  'homem5a9',
#  'homem60a64',
#  'homem65a69',
#  'homem70a74',
#  'homem75a79',
#  'homens80',
#  'homemtot',
#  'mulh0a4',
#  'mulh10a14',
#  'mulh15a19',
#  'mulh20a24',
#  'mulh25a29',
#  'mulh30a34',
#  'mulh35a39',
#  'mulh40a44',
#  'mulh45a49',
#  'mulh50a54',
#  'mulh55a59',
#  'mulh5a9',
#  'mulh60a64',
#  'mulh65a69',
#  'mulh70a74',
#  'mulh75a79',
#  'mulher80',
#  'mulhertot',
#  'pea1014',
#  'pea1517',
#  'pea18m',
#  'peso1',
#  'peso1114',
#  'peso1113',
#  'peso1214',
#  'peso13',
#  'peso15',
#  'peso1517',
#  'peso1524',
#  'peso1618',
#  'peso18',
#  'peso1820',
#  'peso1824',
#  'peso1921',
#  'peso25',
#  'peso4',
#  'peso5',
#  'peso6',
#  'peso610',
#  'peso617',
#  'peso65',
#  'pesom1014',
#  'pesom1517',
#  'pesom15m',
#  'pesom25m',
#  'pesorur',
#  'pesotot',
#  'pesourb',
#  'pia',
#  'pia1014',
#  'pia1517',
#  'pia18m',
#  'pop',
#  't_fbfund_tudo',
#  't_fbmed_tudo',
#  't_fbbas_tudo',
#  't_flfund_tudo',
#  't_flmed_tudo',
#  't_flbas_tudo',
#  't_fund11a13_tudo',
#  'i_escolaridade',
#  'i_freq_prop',
#  'idhm',
#  'idhm_e',
#  'idhm_l',
#  'idhm_r']

# %%
[col for col in df.columns if "esgoto" in col.lower() or "agua" in col.lower() or "lixo" in col.lower()]
# Out:
# ['t_agua', 't_banagua', 't_lixo', 'agua_esgoto']

# %%
pd.read_sql("SELECT * FROM igv_resultado ORDER BY igv DESC LIMIT 50", con)
# Out:
#            cod_id      udh_atlas  \
# 0   1320240500047  1320240500047
# 1   1320130800039  1320130800039
# 2   1320240500026  1320240500026
# 3   1320240500032  1320240500032
# 4   1320240500035  1320240500035
# 5   1320240500028  1320240500028
# 6   1320130800038  1320130800038
# 7   1320240500024  1320240500024
# 8   1320130800011  1320130800011
# 9   1320130800046  1320130800046
# 10  1320520000062  1320520000062
# 11  1320520000040  1320520000040
# 12  1320520000067  1320520000067
# 13  1320500200064  1320500200064
# 14  1320520000048  1320520000048
# 15  1320500200070  1320500200070
# 16  1320500200048  1320500200048
# 17  1320500200007  1320500200007
# 18  1320130800008  1320130800008
# 19  1320130800036  1320130800036
# 20  1320130800003  1320130800003
# 21  1320130800029  1320130800029
# 22  1320130800044  1320130800044
# 23  1320130800012  1320130800012
# 24  1320130800034  1320130800034
# 25  1320510100004  1320510100004
# 26  1320510100009  1320510100009
# 27  1320240500019  1320240500019
# 28  1320510100003  1320510100003
# 29  1320510100013  1320510100013
# 30  1320510100012  1320510100012
# 31  1320510100005  1320510100005
# 32  1320510100014  1320510100014
# 33  1320130800049  1320130800049
# 34  1320240500038  1320240500038
# 35  1320240500043  1320240500043
# 36  1320240500027  1320240500027
# 37  1320240500042  1320240500042
# 38  1320240500030  1320240500030
# 39  1320240500016  1320240500016
# 40  1320240500031  1320240500031
# 41  1320240500021  1320240500021
# 42  1320240500045  1320240500045
# 43  1320240500020  1320240500020
# 44  1320500200001  1320500200001
# 45  1320500200008  1320500200008
# 46  1320130800047  1320130800047
# 47  1320130800035  1320130800035
# 48  1320520000052  1320520000052
# 47      ES  0.531  52.78        0.215833         2.35  0.346907
# 48      ES  0.527  57.11        0.089833         1.76  0.334717
# 49      ES  0.527  57.11        0.082833         1.76  0.333317

# %%
print(pd.read_sql("SELECT name FROM sqlite_master WHERE type='table'", con))
# Out:
#                   name
# 0      indicadores_udh
# 1        igv_resultado
# 2  indicadores_udh_all
# 3    igv_resultado_all

# %%
pd.read_sql("SELECT * FROM igv_resultado LIMIT 5", con)
# Out:
#           cod_id      udh_atlas  \
# 0  1320130800001  1320130800001
# 1  1320130800002  1320130800002
# 2  1320130800003  1320130800003
# 3  1320130800004  1320130800004
# 4  1320130800005  1320130800005
#
#                                             nome_udh        nome_mun nome_uf  \
# 0                                       Campo Grande  Cariacica (ES)      ES
# 1  São Geraldo / Cruzeiro do Sul / Morada de Sant...  Cariacica (ES)      ES
# 2                                        São Conrado  Cariacica (ES)      ES
# 3                            Vera Cruz / São Conrado  Cariacica (ES)      ES
# 4        Jardim América / Vale Esperança / Vera Cruz  Cariacica (ES)      ES
#
#     idhm   ren1  infraestrutura  t_rmaxidoso       igv
# 0  0.778  23.42        0.010267         0.75  0.140413
# 1  0.710  33.84        0.009567         1.30  0.193033
# 2  0.506  56.69        0.197200         2.86  0.363430
# 3  0.670  37.58        0.024733         2.45  0.221587
# 4  0.726  31.27        0.014200         1.93  0.182710

# %%
df_igv = pd.read_sql("SELECT * FROM igv_resultado LIMIT 1", con)
print(df_igv.columns.tolist())
# Out:
# ['cod_id', 'udh_atlas', 'nome_udh', 'nome_mun', 'nome_uf', 'idhm', 'ren1', 'infraestrutura', 't_rmaxidoso', 'igv']

# %%
from pathlib import Path
import sqlite3

db_path = Path("../db/gs2025.db").resolve()  # ajuste o caminho se estiver em notebooks/
print("Usando banco:", db_path)

conn = sqlite3.connect(db_path)
# Out:
# Usando banco: C:\GitHub\Global Solution 1\db\gs2025.db

# %%
import pandas as pd
import sqlite3
from pathlib import Path

db_path = Path("C:/GitHub/Global Solution 1/db/gs2025.db")
conn = sqlite3.connect(db_path)

# Verifica tabelas existentes
print(pd.read_sql("SELECT name FROM sqlite_master WHERE type='table'", conn))
# Out:
#                   name
# 0      indicadores_udh
# 1        igv_resultado
# 2  indicadores_udh_all
# 3    igv_resultado_all

# %%
df_igv = pd.read_sql("SELECT * FROM igv_resultado ORDER BY igv DESC", conn)

import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.barh(df_igv["nome_udh"], df_igv["igv"], color='tomato')
plt.xlabel("IGV (quanto maior, mais vulnerável)")
plt.title("Top 10 UDHs mais vulneráveis")
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %%
from pathlib import Path

# Caminho base para a pasta 'dados'
base_dir = Path("../dados").resolve()  # ajuste o caminho se necessário

# Lista para armazenar os caminhos completos
arquivos = []

for file in base_dir.rglob("*"):
    if file.is_file():
        arquivos.append(str(file))

print(f"Total de arquivos encontrados: {len(arquivos)}")
for path in arquivos:
    print(path)
# Out:
# Total de arquivos encontrados: 426
# C:\GitHub\Global Solution 1\dados\ADH_BASE_RADAR_2012-2021.xlsx
# C:\GitHub\Global Solution 1\dados\ADH_METADADOS_RADAR.xlsx
# C:\GitHub\Global Solution 1\dados\Agregações de UDHs para fins de extração de dados.xlsx
# C:\GitHub\Global Solution 1\dados\dados_belem.zip
# C:\GitHub\Global Solution 1\dados\dados_bh.zip
# C:\GitHub\Global Solution 1\dados\dados_bs.zip
# C:\GitHub\Global Solution 1\dados\dados_campinas.zip
# C:\GitHub\Global Solution 1\dados\dados_cuiaba.zip
# C:\GitHub\Global Solution 1\dados\dados_curitiba.zip
# C:\GitHub\Global Solution 1\dados\dados_df.zip
# C:\GitHub\Global Solution 1\dados\dados_florianopolis.zip
# C:\GitHub\Global Solution 1\dados\dados_fortaleza.zip
# C:\GitHub\Global Solution 1\dados\dados_goiania.zip
# C:\GitHub\Global Solution 1\dados\dados_maceio.zip
# C:\GitHub\Global Solution 1\dados\dados_manaus.zip
# C:\GitHub\Global Solution 1\dados\dados_natal.zip
# C:\GitHub\Global Solution 1\dados\dados_pa.zip
# C:\GitHub\Global Solution 1\dados\dados_petrolina_juazeiro.zip
# C:\GitHub\Global Solution 1\dados\dados_recife.zip
# C:\GitHub\Global Solution 1\dados\dados_rj.zip
# C:\GitHub\Global Solution 1\dados\dados_salvador.zip
# C:\GitHub\Global Solution 1\dados\dados_sl.zip
# C:\GitHub\Global Solution 1\dados\dados_sorocaba.zip
# C:\GitHub\Global Solution 1\dados\dados_sp.zip
# C:\GitHub\Global Solution 1\dados\dados_teresina_timon.zip
# C:\GitHub\Global Solution 1\dados\dados_valedoparaiba.zip
# C:\GitHub\Global Solution 1\dados\dados_vitoria.zip
# C:\GitHub\Global Solution 1\dados\gs2025.db
# C:\GitHub\Global Solution 1\dados\IPS Brasil 2025 - Digital.pdf
# C:\GitHub\Global Solution 1\dados\BR_Municipios_2024\BR_Municipios_2024.cpg
# C:\GitHub\Global Solution 1\dados\BR_Municipios_2024\BR_Municipios_2024.dbf
# C:\GitHub\Global Solution 1\dados\BR_Municipios_2024\BR_Municipios_2024.prj
# C:\GitHub\Global Solution 1\dados\BR_Municipios_2024\BR_Municipios_2024.shp
# C:\GitHub\Global Solution 1\dados\BR_Municipios_2024\BR_Municipios_2024.shx
# C:\GitHub\Global Solution 1\dados\dados_belem\base final RM Belém.rar
# C:\GitHub\Global Solution 1\dados\dados_belem\SH RM_Belem.rar
# C:\GitHub\Global Solution 1\dados\dados_bh\base final RM Belo Horizonte.rar
# C:\GitHub\Global Solution 1\dados\dados_bh\SH RM_Belo_Horizonte.rar
# C:\GitHub\Global Solution 1\dados\dados_bs\base final RM Baixada Santista.rar
# C:\GitHub\Global Solution 1\dados\dados_bs\SH RM_Baixada_Santista.rar
# C:\GitHub\Global Solution 1\dados\dados_campinas\Base final RM Campinas.rar
# C:\GitHub\Global Solution 1\dados\dados_campinas\SH RM_Campinas.rar
# C:\GitHub\Global Solution 1\dados\dados_cuiaba\base final RM Cuiabá.rar
# C:\GitHub\Global Solution 1\dados\dados_cuiaba\SH RM_Cuiaba.rar
# C:\GitHub\Global Solution 1\dados\dados_curitiba\base final RM Curitiba.rar
# C:\GitHub\Global Solution 1\dados\dados_curitiba\SH RM_Curitiba.rar
# C:\GitHub\Global Solution 1\dados\dados_df\base final RIDE DF.rar
# C:\GitHub\Global Solution 1\dados\dados_df\SH RIDE_DF.rar
# C:\GitHub\Global Solution 1\dados\dados_fortaleza\base final RM Fortaleza.rar
# C:\GitHub\Global Solution 1\dados\dados_fortaleza\SH RM_Fortaleza.rar
# C:\GitHub\Global Solution 1\dados\dados_goiania\base final RM Goiania.rar
# C:\GitHub\Global Solution 1\dados\dados_goiania\SH RM_Goiania.rar
# C:\GitHub\Global Solution 1\dados\dados_maceio\base final RM Maceió.rar
# C:\GitHub\Global Solution 1\dados\dados_maceio\SH RM_Maceio.rar
# C:\GitHub\Global Solution 1\dados\dados_manaus\base final RM Manaus.rar
# C:\GitHub\Global Solution 1\dados\dados_manaus\SH RM_Manaus.rar
# C:\GitHub\Global Solution 1\dados\dados_natal\base final RM Natal.rar
# C:\GitHub\Global Solution 1\dados\dados_natal\SH RM_Natal.rar
# C:\GitHub\Global Solution 1\dados\dados_pa\base final RM Porto Alegre.rar
# C:\GitHub\Global Solution 1\dados\dados_pa\SH RM_Porto_Alegre.rar
# C:\GitHub\Global Solution 1\dados\dados_recife\base final RM Recife.rar
# C:\GitHub\Global Solution 1\dados\dados_recife\SH RM_Recife.rar
# C:\GitHub\Global Solution 1\dados\dados_rj\base final RM Rio de Janeiro.rar
# C:\GitHub\Global Solution 1\dados\dados_rj\SH RM_Rio_de_Janeiro.rar
# C:\GitHub\Global Solution 1\dados\dados_salvador\base final RM Salvador.rar
# C:\GitHub\Global Solution 1\dados\dados_salvador\SH RM_Salvador.rar
# C:\GitHub\Global Solution 1\dados\dados_sl\base final RM São Luís.rar
# C:\GitHub\Global Solution 1\dados\dados_sl\SH RM_Sao_Luis.rar
# C:\GitHub\Global Solution 1\dados\dados_sp\base final RM São Paulo.rar
# C:\GitHub\Global Solution 1\dados\dados_sp\SH RM São Paulo.rar
# C:\GitHub\Global Solution 1\dados\dados_valedoparaiba\base final RM VParaiba.rar
# C:\GitHub\Global Solution 1\dados\dados_valedoparaiba\SH RM_Vale_Paraiba.rar
# C:\GitHub\Global Solution 1\dados\dados_vitoria\base final RM Vitória.rar
# C:\GitHub\Global Solution 1\dados\dados_vitoria\SH RM_Vitoria.rar
# C:\GitHub\Global Solution 1\dados\dados_vitoria\base final RM Vitória\A - Base 20 RMs 2000_2010.xlsx
# C:\GitHub\Global Solution 1\dados\dados_vitoria\base final RM Vitória\A - DICIONÁRIO dos indicadores do Atlas.xlsx
# C:\GitHub\Global Solution 1\dados\dados_vitoria\base final RM Vitória\RM 63200 Vitória - Base REGIONAL 2000_2010.xlsx
# C:\GitHub\Global Solution 1\dados\dados_vitoria\base final RM Vitória\RM 63200 Vitória - Base UDH 2000_2010.xlsx
# C:\GitHub\Global Solution 1\dados\dados_vitoria\SH RM_Vitoria\RM_Vitoria_Regional_2_region.dbf
# C:\GitHub\Global Solution 1\dados\dados_vitoria\SH RM_Vitoria\RM_Vitoria_Regional_2_region.prj
# C:\GitHub\Global Solution 1\dados\dados_vitoria\SH RM_Vitoria\RM_Vitoria_Regional_2_region.shp
# C:\GitHub\Global Solution 1\dados\dados_vitoria\SH RM_Vitoria\RM_Vitoria_Regional_2_region.shx
# C:\GitHub\Global Solution 1\dados\dados_vitoria\SH RM_Vitoria\RM_Vitoria_RM_2_region.dbf
# C:\GitHub\Global Solution 1\dados\dados_vitoria\SH RM_Vitoria\RM_Vitoria_RM_2_region.prj
# C:\GitHub\Global Solution 1\dados\dados_vitoria\SH RM_Vitoria\RM_Vitoria_RM_2_region.shp
# C:\GitHub\Global Solution 1\dados\dados_vitoria\SH RM_Vitoria\RM_Vitoria_RM_2_region.shx
# C:\GitHub\Global Solution 1\dados\dados_vitoria\SH RM_Vitoria\RM_Vitoria_UDH_2_region.dbf
# C:\GitHub\Global Solution 1\dados\dados_vitoria\SH RM_Vitoria\RM_Vitoria_UDH_2_region.prj
# C:\GitHub\Global Solution 1\dados\dados_vitoria\SH RM_Vitoria\RM_Vitoria_UDH_2_region.shp
# C:\GitHub\Global Solution 1\dados\dados_vitoria\SH RM_Vitoria\RM_Vitoria_UDH_2_region.shx
# C:\GitHub\Global Solution 1\dados\dados_valedoparai
A - DICIONÁRIO dos indicadores do Atlas.xlsx
# C:\GitHub\Global Solution 1\dados\dados_bh\base final RM Belo Horizonte\RM 63100 Belo Horizonte - Base REGIONAL 2000_2010.xlsx
# C:\GitHub\Global Solution 1\dados\dados_bh\base final RM Belo Horizonte\RM 63100 Belo Horizonte - Base UDH 2000_2010.xlsx
# C:\GitHub\Global Solution 1\dados\dados_bh\SH RM_Belo_Horizonte\RM_BeloHorizonte_Regional_region.dbf
# C:\GitHub\Global Solution 1\dados\dados_bh\SH RM_Belo_Horizonte\RM_BeloHorizonte_Regional_region.prj
# C:\GitHub\Global Solution 1\dados\dados_bh\SH RM_Belo_Horizonte\RM_BeloHorizonte_Regional_region.shp
# C:\GitHub\Global Solution 1\dados\dados_bh\SH RM_Belo_Horizonte\RM_BeloHorizonte_Regional_region.shx
# C:\GitHub\Global Solution 1\dados\dados_bh\SH RM_Belo_Horizonte\RM_BeloHorizonte_RM_region.dbf
# C:\GitHub\Global Solution 1\dados\dados_bh\SH RM_Belo_Horizonte\RM_BeloHorizonte_RM_region.prj
# C:\GitHub\Global Solution 1\dados\dados_bh\SH RM_Belo_Horizonte\RM_BeloHorizonte_RM_region.shp
# C:\GitHub\Global Solution 1\dados\dados_bh\SH RM_Belo_Horizonte\RM_BeloHorizonte_RM_region.shx
# C:\GitHub\Global Solution 1\dados\dados_bh\SH RM_Belo_Horizonte\RM_BeloHorizonte_UDH_region.dbf
# C:\GitHub\Global Solution 1\dados\dados_bh\SH RM_Belo_Horizonte\RM_BeloHorizonte_UDH_region.prj
# C:\GitHub\Global Solution 1\dados\dados_bh\SH RM_Belo_Horizonte\RM_BeloHorizonte_UDH_region.shp
# C:\GitHub\Global Solution 1\dados\dados_bh\SH RM_Belo_Horizonte\RM_BeloHorizonte_UDH_region.shx
# C:\GitHub\Global Solution 1\dados\dados_belem\base final RM Belém\A - Base 20 RMs 2000_2010.xlsx
# C:\GitHub\Global Solution 1\dados\dados_belem\base final RM Belém\A - DICIONÁRIO dos indicadores do Atlas.xlsx
# C:\GitHub\Global Solution 1\dados\dados_belem\base final RM Belém\RM 61500 Belém - Base UDH 2000_2010.xlsx
# C:\GitHub\Global Solution 1\dados\dados_belem\SH RM_Belem\RM_Belem_RM_region.dbf
# C:\GitHub\Global Solution 1\dados\dados_belem\SH RM_Belem\RM_Belem_RM_region.prj
# C:\GitHub\Global Solution 1\dados\dados_belem\SH RM_Belem\RM_Belem_RM_region.shp
# C:\GitHub\Global Solution 1\dados\dados_belem\SH RM_Belem\RM_Belem_RM_region.shx
# C:\GitHub\Global Solution 1\dados\dados_belem\SH RM_Belem\RM_Belem_UDH_region.dbf
# C:\GitHub\Global Solution 1\dados\dados_belem\SH RM_Belem\RM_Belem_UDH_region.prj
# C:\GitHub\Global Solution 1\dados\dados_belem\SH RM_Belem\RM_Belem_UDH_region.shp
# C:\GitHub\Global Solution 1\dados\dados_belem\SH RM_Belem\RM_Belem_UDH_region.shx

# %%
# === 1. Imports ===
import sqlite3
import pandas as pd
from pathlib import Path

# === 2. Caminho do banco de dados ===
DB_PATH = Path("../db/gs2025.db").resolve()  # ajuste o caminho se necessário

# === 3. Conexão e leitura da tabela ===
conn = sqlite3.connect(DB_PATH)
df = pd.read_sql("SELECT DISTINCT regiao FROM igv_resultado_all ORDER BY regiao", conn)
conn.close()

# === 4. Visualização dos nomes únicos de região ===
print("🧭 Regiões encontradas no banco:")
display(df)
# Out:
# 🧭 Regiões encontradas no banco:
#                 regiao
# 0                belem
# 1                   bh
# 2                   bs
# 3             campinas
# 4               cuiaba
# 5             curitiba
# 6                   df
# 7        florianopolis
# 8            fortaleza
# 9              goiania
# 10              maceio
# 11              manaus
# 12               natal
# 13                  pa
# 14  petrolina_juazeiro
# 15              recife
# 16                  rj
# 17            salvador
# 18                  sl
# 19            sorocaba
# 20                  sp
# 21      teresina_timon
# 22       valedoparaiba
# 23             vitoria
